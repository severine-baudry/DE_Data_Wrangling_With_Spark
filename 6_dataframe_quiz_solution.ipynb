# %% [markdown]
# # Answer Key to the Data Wrangling with DataFrames Coding Quiz
#
# Helpful resources:
# http://spark.apache.org/docs/latest/api/python/pyspark.sql.html

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import isnan, count, when, col, desc, udf, col, sort_array, asc, avg
from pyspark.sql.functions import sum as Fsum
from pyspark.sql.window import Window
from pyspark.sql.types import IntegerType

# %%
# 1) import any other libraries you might need
# 2) instantiate a Spark session 
# 3) read in the data set located at the path "data/sparkify_log_small.json"
# 4) write code to answer the quiz questions 

spark = SparkSession \
    .builder \
    .appName("Data Frames practice") \
    .getOrCreate()

df = spark.read.json("data/sparkify_log_small.json")

# %% [markdown]
# # Question 1
#
# Which page did user id "" (empty string) NOT visit?

# %%
df.printSchema()

# %%
# filter for users with blank user id
blank_pages = df.filter(df.userId == '') \
    .select(col('page') \
    .alias('blank_pages')) \
    .dropDuplicates()

# get a list of possible pages that could be visited
all_pages = df.select('page').dropDuplicates()

# find values in all_pages that are not in blank_pages
# these are the pages that the blank user did not go to
for row in set(all_pages.collect()) - set(blank_pages.collect()):
    print(row.page)

# %% [markdown]
# # Question 2 - Reflect
#
# What type of user does the empty string user id most likely refer to?

# %% [markdown]
# Perhaps it represents users who have not signed up yet or who are signed out and are about to log in.

# %% [markdown]
# # Question 3
#
# How many female users do we have in the data set?

# %%
df.filter(df.gender == 'F') \
    .select('userId', 'gender') \
    .dropDuplicates() \
    .count()

# %% [markdown]
# # Question 4
#
# How many songs were played from the most played artist?

# %%
df.filter(df.page == 'NextSong') \
    .select('Artist') \
    .groupBy('Artist') \
    .agg({'Artist':'count'}) \
    .withColumnRenamed('count(Artist)', 'Artistcount') \
    .sort(desc('Artistcount')) \
    .show(1)

# %% [markdown]
# # Question 5 (challenge)
#
# How many songs do users listen to on average between visiting our home page? Please round your answer to the closest integer.

# %%
# TODO: filter out 0 sum and max sum to get more exact answer

function = udf(lambda ishome : int(ishome == 'Home'), IntegerType())

user_window = Window \
    .partitionBy('userID') \
    .orderBy(desc('ts')) \
    .rangeBetween(Window.unboundedPreceding, 0)

cusum = df.filter((df.page == 'NextSong') | (df.page == 'Home')) \
    .select('userID', 'page', 'ts') \
    .withColumn('homevisit', function(col('page'))) \
    .withColumn('period', Fsum('homevisit').over(user_window))

cusum.filter((cusum.page == 'NextSong')) \
    .groupBy('userID', 'period') \
    .agg({'period':'count'}) \
    .agg({'count(period)':'avg'}).show()
# Out:
# +------------------+
# |avg(count(period))|
# +------------------+
# | 6.898347107438017|
# +------------------+

# %%
cusum.select("userId", "homevisit", "period" ).collect()
# Out:
# [Row(userId='1436', homevisit=0, period=0),
#  Row(userId='1436', homevisit=0, period=0),
#  Row(userId='2088', homevisit=1, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2088', homevisit=0, period=1),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=0, period=0),
#  Row(userId='2162', homevisit=1, period=1),
#  Row(userId='2162', homevisit=1, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2162', homevisit=0, period=2),
#  Row(userId='2294', homevisit=0, period=0),
#  Row(userId='2294', homevisit=0, period=0),
#  Row(userId='2294', homevisit=0, period=0),
#  Row(userId='2294', homevisit=0, period=0),
#  Row(userId='2294', homevisit=1, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=0, period=1),
#  Row(userId='2294', homevisit=1, period=2),
#  Row(userId='2294', homevisit=0, period=2),
#  Row(userId='2294', homevisit=0, period=2),
#  Row(userId='2294', homevisit=0, period=2),
#  Row(userId='2294', homevisit=1, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=0, period=3),
#  Row(userId='2294', homevisit=1, period=4),
#  Row(userId='2294', homevisit=0, period=4),
#  Row(userId='2294', homevisit=0, period=4),
#  Row(userId='2294', homevisit=0, period=4),
#  Row(userId='2294', homevisit=0, period=4),
#  Row(userId='2294', homevisit=1, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2294', homevisit=0, period=5),
#  Row(userId='2904', homevisit=0, period=0),
#  Row(userId='691', homevisit=1, period=1),
#  Row(userId='691', homevisit=0, period=1),
#  Row(userId='691', homevisit=0, period=1),
#  Row(userId='691', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=0, period=0),
#  Row(userId='1394', homevisit=1, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='1394', homevisit=0, period=1),
#  Row(userId='2275', homevisit=0, period=0),
#  Row(userId='2275', homevisit=0, period=0),
#  Row(userId='2275', homevisit=0, period=0),
#  Row(userId='2275', homevisit=1, period=1),
#  Row(userId='2756', homevisit=0, period=0),
#  Row(userId='2756', homevisit=0, period=0),
#  Row(userId='2756', homevisit=0, period=0),
#  Row(userId='2756', homevisit=0, period=0),
#  Row(userId='2756', homevisit=1, period=1),
#  Row(userId='2756', homevisit=1, period=2),
#  Row(userId='2756', homevisit=0, period=2),
#  Row(userId='451', homevisit=0, period=0),
#  Row(userId='451', homevisit=1, period=1),
#  Row(userId='451', homevisit=0, period=1),
#  Row(userId='451', homevisit=1, period=2),
#  Row(userId='800', homevisit=1, period=1),
#  Row(userId='800', homevisit=0, period=1),
#  Row(userId='800', homevisit=0, period=1),
#  Row(userId='1280', homevisit=1, period=1),
#  Row(userId='1280', homevisit=1, period=2),
#  Row(userId='1746', homevisit=1, period=1),
#  Row(userId='1746', homevisit=1, period=2),
#  Row(userId='2696', homevisit=0, period=0),
#  Row(userId='2696', homevisit=1, period=1),
#  Row(userId='870', homevisit=0, period=0),
#  Row(userId='870', homevisit=0, period=0),
#  Row(userId='926', homevisit=0, period=0),
#  Row(userId='926', homevisit=0, period=0),
#  Row(userId='926', homevisit=1, period=1),
#  Row(userId='926', homevisit=0, period=1),
#  Row(userId='926', homevisit=0, period=1),
#  Row(userId='926', homevisit=1, period=2),
#  Row(userId='926', homevisit=1, period=3),
#  Row(userId='1903', homevisit=1, period=1),
#  Row(userId='1903', homevisit=0, period=1),
#  Row(userId='1903', homevisit=0, period=1),
#  Row(userId='1903', homevisit=0, period=1),
#  Row(userId='1903', homevisit=0, period=1),
#  Row(userId='1903', homevisit=0, period=1),
#  Row(userId='1903', homevisit=1, period=2),
#  Row(userId='591', homevisit=0, period=0),
#  Row(userId='7', homevisit=0, period=0),
#  Row(userId='7', homevisit=0, period=0),
#  Row(userId='307', homevisit=0, period=0),
#  Row(userId='574', homevisit=1, period=1),
#  Row(userId='574', homevisit=0, period=1),
#  Row(userId='574', homevisit=0, period=1),
#  Row(userId='574', homevisit=0, period=1),
#  Row(userId='574', homevisit=0, period=1),
#  Row(userId='574', homevisit=1, period=2),
#  Row(userId='613', homevisit=0, period=0),
#  Row(userId='613', homevisit=1, period=1),
#  Row(userId='613', homevisit=0, period=1),
#  Row(userId='1043', homevisit=0, period=0),
#  Row(userId='1043', homevisit=1, period=1),
#  Row(userId='2402', homevisit=0, period=0),
#  Row(userId='2402', homevisit=0, period=0),
#  Row(userId='2402', homevisit=0, period=0),
#  Row(userId='2402', homevisit=1, period=1),
#  Row(userId='2644', homevisit=0, period=0),
#  Row(userId='577', homevisit=0, period=0),
#  Row(userId='577', homevisit=1, period=1),
#  Row(userId='1349', homevisit=0, period=0),
#  Row(userId='1349', homevisit=0, period=0),
#  Row(userId='1349', homevisit=0, period=0),
#  Row(userId='1349', homevisit=0, period=0),
#  Row(userId='1349', homevisit=0, period=0),
#  Row(userId='1349', homevisit=1, period=1),
#  Row(userId='1349', homevisit=0, period=1),
#  Row(userId='1349', homevisit=0, period=1),
#  Row(userId='1349', homevisit=0, period=1),
#  Row(userId='1349', homevisit=0, period=1),
#  Row(userId='1349', homevisit=0, period=1),
#  Row(userId='1349', homevisit=0, period=1),
#  Row(userId='1418', homevisit=0, period=0),
#  Row(userId='1418', homevisit=0, period=0),
#  Row(userId='1418', homevisit=0, period=0),
#  Row(userId='1418', homevisit=0, period=0),
#  Row(userId='2200', homevisit=1, period=1),
#  Row(userId='2392', homevisit=0, period=0),
#  Row(userId='2531', homevisit=1, period=1),
#  Row(userId='2964', homevisit=1, period=1),
#  Row(userId='2980', homevisit=0, period=0),
#  Row(userId='2980', homevisit=0, period=0),
#  Row(userId='2980', homevisit=0, period=0),
#  Row(userId='2980', homevisit=1, period=1),
#  Row(userId='2980', homevisit=0, period=1),
#  Row(userId='2980', homevisit=0, period=1),
#  Row(userId='2980', homevisit=1, period=2),
#  Row(userId='442', homevisit=0, period=0),
#  Row(userId='442', homevisit=0, period=0),
#  Row(userId='442', homevisit=0, period=0),
#  Row(userId='442', homevisit=0, period=0),
#  Row(userId='442', homevisit=0, period=0),
#  Row(userId='442', homevisit=0, period=0),
#  Row(userId='442', homevisit=1, period=1),
#  Row(userId='462', homevisit=1, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=0, period=1),
#  Row(userId='462', homevisit=1, period=2),
#  Row(userId='462', homevisit=1, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=0, period=3),
#  Row(userId='462', homevisit=1, period=4),
#  Row(userId='647', homevisit=1, period=1),
#  Row(userId='1686', homevisit=0, period=0),
#  Row(userId='1686', homevisit=0, period=0),
#  Row(userId='1686', homevisit=0, period=0),
#  Row(userId='1686', homevisit=0, period=0),
#  Row(userId='1686', homevisit=1, period=1),
#  Row(userId='2628', homevisit=1, period=1),
#  Row(userId='2628', homevisit=0, period=1),
#  Row(userId='2628', homevisit=0, period=1),
#  Row(userId='2720', homevisit=0, period=0),
#  Row(userId='282', homevisit=0, period=0),
#  Row(userId='282', homevisit=0, period=0),
#  Row(userId='282', homevisit=1, period=1),
#  Row(userId='282', homevisit=1, period=2),
#  Row(userId='282', homevisit=0, period=2),
#  Row(userId='282', homevisit=1, period=3),
#  Row(userId='282', homevisit=1, period=4),
#  Row(userId='448', homevisit=0, period=0),
#  Row(userId='700', homevisit=0, period=0),
#  Row(userId='700', homevisit=1, period=1),
#  Row(userId='700', homevisit=0, period=1),
#  Row(userId='700', homevisit=0, period=1),
#  Row(userId='700', homevisit=1, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=0, period=2),
#  Row(userId='700', homevisit=1, period=3),
#  Row(userId='700', homevisit=0, period=3),
#  Row(userId='700', homevisit=0, period=3),
#  Row(userId='700', homevisit=0, period=3),
#  Row(userId='700', homevisit=1, period=4),
#  Row(userId='1158', homevisit=0, period=0),
#  Row(userId='1158', homevisit=0, period=0),
#  Row(userId='1158', homevisit=0, period=0),
#  Row(userId='1158', homevisit=0, period=0),
#  Row(userId='1158', homevisit=0, period=0),
#  Row(userId='1158', homevisit=0, period=0),
#  Row(userId='1158', homevisit=1, period=1),
#  Row(userId='1158', homevisit=0, period=1),
#  Row(userId='1158', homevisit=0, period=1),
#  Row(userId='1158', homevisit=1, period=2),
#  Row(userId='1304', homevisit=0, period=0),
#  Row(userId='1377', homevisit=0, period=0),
#  Row(userId='1377', homevisit=1, period=1),
#  Row(userId='1377', homevisit=0, period=1),
#  Row(userId='1412', homevisit=1, period=1),
#  Row(userId='2415', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2812', homevisit=0, period=0),
#  Row(userId='2988', homevisit=0, period=0),
#  Row(userId='2988', homevisit=1, period=1),
#  Row(userId='635', homevisit=1, period=1),
#  Row(userId='862', homevisit=1, period=1),
#  Row(userId='2079', homevisit=0, period=0),
#  Row(userId='2079', homevisit=1, period=1),
#  Row(userId='2079', homevisit=0, period=1),
#  Row(userId='2079', homevisit=0, period=1),
#  Row(userId='2079', homevisit=0, period=1),
#  Row(userId='2079', homevisit=0, period=1),
#  Row(userId='2079', homevisit=0, period=1),
#  Row(userId='714', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=0, period=0),
#  Row(userId='1290', homevisit=1, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=0, period=1),
#  Row(userId='1290', homevisit=1, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=0, period=2),
#  Row(userId='1290', homevisit=1, period=3),
#  Row(userId='1290', homevisit=0, period=3),
#  Row(userId='1290', homevisit=0, period=3),
#  Row(userId='1290', homevisit=1, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=0, period=4),
#  Row(userId='1290', homevisit=1, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=0, period=5),
#  Row(userId='1290', homevisit=1, period=6),
#  Row(userId='1290', homevisit=0, period=6),
#  Row(userId='1290', homevisit=0, period=6),
#  Row(userId='1290', homevisit=0, period=6),
#  Row(userId='1290', homevisit=0, period=6),
#  Row(userId='1290', homevisit=0, period=6),
#  Row(userId='1290', homevisit=1, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='1290', homevisit=0, period=7),
#  Row(userId='200', homevisit=0, period=0),
#  Row(userId='2020', homevisit=0, period=0),
#  Row(userId='2020', homevisit=0, period=0),
#  Row(userId='2020', homevisit=0, period=0),
#  Row(userId='2020', homevisit=0, period=0),
#  Row(userId='2020', homevisit=1, period=1),
#  Row(userId='2115', homevisit=0, period=0),
#  Row(userId='2115', homevisit=0, period=0),
#  Row(userId='2115', homevisit=1, period=1),
#  Row(userId='2115', homevisit=1, period=2),
#  Row(userId='625', homevisit=0, period=0),
#  Row(userId='625', homevisit=1, period=1),
#  Row(userId='11', homevisit=0, period=0),
#  Row(userId='11', homevisit=0, period=0),
#  Row(userId='11', homevisit=1, period=1),
#  Row(userId='1259', homevisit=0, period=0),
#  Row(userId='1259', homevisit=0, period=0),
#  Row(userId='1259', homevisit=0, period=0),
#  Row(userId='2354', homevisit=0, period=0),
#  Row(userId='2354', homevisit=1, period=1),
#  Row(userId='986', homevisit=0, period=0),
#  Row(userId='986', homevisit=0, period=0),
#  Row(userId='986', homevisit=0, period=0),
#  Row(userId='986', homevisit=0, period=0),
#  Row(userId='986', homevisit=0, period=0),
#  Row(userId='986', homevisit=1, period=1),
#  Row(userId='986', homevisit=0, period=1),
#  Row(userId='415', homevisit=0, period=0),
#  Row(userId='415', homevisit=0, period=0),
#  Row(userId='415', homevisit=0, period=0),
#  Row(userId='422', homevisit=0, period=0),
#  Row(userId='422', homevisit=0, period=0),
#  Row(userId='422', homevisit=1, period=1),
#  Row(userId='422', homevisit=0, period=1),
#  Row(userId='422', homevisit=1, period=2),
#  Row(userId='685', homevisit=0, period=0),
#  Row(userId='685', homevisit=0, period=0),
#  Row(userId='685', homevisit=1, period=1),
#  Row(userId='685', homevisit=0, period=1),
#  Row(userId='685', homevisit=0, period=1),
#  Row(userId='685', homevisit=0, period=1),
#  Row(userId='685', homevisit=1, period=2),
#  Row(userId='979', homevisit=0, period=0),
#  Row(userId='979', homevisit=1, period=1),
#  Row(userId='979', homevisit=0, period=1),
#  Row(userId='979', homevisit=0, period=1),
#  Row(userId='979', homevisit=0, period=1),
#  Row(userId='979', homevisit=1, period=2),
#  Row(userId='138', homevisit=1, period=1),
#  Row(userId='1497', homevisit=0, period=0),
#  Row(userId='1497', homevisit=0, period=0),
#  Row(userId='1497', homevisit=1, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=0, period=1),
#  Row(userId='1497', homevisit=1, period=2),
#  Row(userId='323', homevisit=1, period=1),
#  Row(userId='361', homevisit=1, period=1),
#  Row(userId='387', homevisit=0, period=0),
#  Row(userId='387', homevisit=0, period=0),
#  Row(userId='387', homevisit=1, period=1),
#  Row(userId='387', homevisit=0, period=1),
#  Row(userId='387', homevisit=0, period=1),
#  Row(userId='387', homevisit=0, period=1),
#  Row(userId='961', homevisit=0, period=0),
#  Row(userId='961', homevisit=0, period=0),
#  Row(userId='961', homevisit=0, period=0),
#  Row(userId='961', homevisit=1, period=1),
#  Row(userId='961', homevisit=1, period=2),
#  Row(userId='1205', homevisit=0, period=0),
#  Row(userId='1205', homevisit=1, period=1),
#  Row(userId='1943', homevisit=0, period=0),
#  Row(userId='1943', homevisit=1, period=1),
#  Row(userId='2201', homevisit=0, period=0),
#  Row(userId='2201', homevisit=0, period=0),
#  Row(userId='2201', homevisit=0, period=0),
#  Row(userId='2201', homevisit=0, period=0),
#  Row(userId='2201', homevisit=0, period=0),
#  Row(userId='2201', homevisit=0, period=0),
#  Row(userId='2201', homevisit=0, period=0),
#  Row(userId='2443', homevisit=0, period=0),
#  Row(userId='419', homevisit=0, period=0),
#  Row(userId='419', homevisit=0, period=0),
#  Row(userId='419', homevisit=0, period=0),
#  Row(userId='419', homevisit=0, period=0),
#  Row(userId='724', homevisit=0, period=0),
#  Row(userId='724', homevisit=0, period=0),
#  Row(userId='724', homevisit=0, period=0),
#  Row(userId='724', homevisit=0, period=0),
#  Row(userId='724', homevisit=0, period=0),
#  Row(userId='724', homevisit=1, period=1),
#  Row(userId='724', homevisit=0, period=1),
#  Row(userId='724', homevisit=0, period=1),
#  Row(userId='724', homevisit=0, period=1),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2587', homevisit=0, period=0),
#  Row(userId='2799', homevisit=1, period=1),
#  Row(userId='534', homevisit=0, period=0),
#  Row(userId='534', homevisit=1, period=1),
#  Row(userId='863', homevisit=0, period=0),
#  Row(userId='863', homevisit=0, period=0),
#  Row(userId='863', homevisit=0, period=0),
#  Row(userId='1915', homevisit=0, period=0),
#  Row(userId='1915', homevisit=0, period=0),
#  Row(userId='1915', homevisit=0, period=0),
#  Row(userId='1915', homevisit=1, period=1),
#  Row(userId='1915', homevisit=0, period=1),
#  Row(userId='1915', homevisit=0, period=1),
#  Row(userId='1915', homevisit=0, period=1),
#  Row(userId='2772', homevisit=0, period=0),
#  Row(userId='2784', homevisit=0, period=0),
#  Row(userId='686', homevisit=0, period=0),
#  Row(userId='686', homevisit=0, period=0),
#  Row(userId='890', homevisit=0, period=0),
#  Row(userId='890', homevisit=0, period=0),
#  Row(userId='890', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=0, period=0),
#  Row(userId='974', homevisit=1, period=1),
#  Row(userId='1429', homevisit=1, period=1),
#  Row(userId='1429', homevisit=0, period=1),
#  Row(userId='1584', homevisit=1, period=1),
#  Row(userId='1584', homevisit=0, period=1),
#  Row(userId='1584', homevisit=0, period=1),
#  Row(userId='1584', homevisit=0, period=1),
#  Row(userId='1584', homevisit=0, period=1),
#  Row(userId='1584', homevisit=1, period=2),
#  Row(userId='1584', homevisit=0, period=2),
#  Row(userId='1972', homevisit=0, period=0),
#  Row(userId='1972', homevisit=0, period=0),
#  Row(userId='2224', homevisit=0, period=0),
#  Row(userId='2224', homevisit=0, period=0),
#  Row(userId='2349', homevisit=0, period=0),
#  Row(userId='2349', homevisit=0, period=0),
#  Row(userId='2349', homevisit=0, period=0),
#  Row(userId='2349', homevisit=1, period=1),
#  Row(userId='2349', homevisit=1, period=2),
#  Row(userId='308', homevisit=1, period=1),
#  Row(userId='308', homevisit=0, period=1),
#  Row(userId='308', homevisit=0, period=1),
#  Row(userId='308', homevisit=0, period=1),
#  Row(userId='308', homevisit=0, period=1),
#  Row(userId='308', homevisit=1, period=2),
#  Row(userId='308', homevisit=0, period=2),
#  Row(userId='308', homevisit=0, period=2),
#  Row(userId='308', homevisit=0, period=2),
#  Row(userId='308', homevisit=0, period=2),
#  Row(userId='308', homevisit=1, period=3),
#  Row(userId='308', homevisit=0, period=3),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='459', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=0, period=0),
#  Row(userId='512', homevisit=1, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=0, period=1),
#  Row(userId='512', homevisit=1, period=2),
#  Row(userId='512', homevisit=1, period=3),
#  Row(userId='64', homevisit=0, period=0),
#  Row(userId='64', homevisit=1, period=1),
#  Row(userId='710', homevisit=0, period=0),
#  Row(userId='710', homevisit=0, period=0),
#  Row(userId='710', homevisit=0, period=0),
#  Row(userId='710', homevisit=0, period=0),
#  Row(userId='2111', homevisit=0, period=0),
#  Row(userId='2111', homevisit=0, period=0),
#  Row(userId='2111', homevisit=0, period=0),
#  Row(userId='2111', homevisit=0, period=0),
#  Row(userId='2111', homevisit=0, period=0),
#  Row(userId='2111', homevisit=1, period=1),
#  Row(userId='2699', homevisit=0, period=0),
#  Row(userId='2942', homevisit=0, period=0),
#  Row(userId='2942', homevisit=0, period=0),
#  Row(userId='2942', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=0, period=0),
#  Row(userId='446', homevisit=1, period=1),
#  Row(userId='446', homevisit=0, period=1),
#  Row(userId='446', homevisit=0, period=1),
#  Row(userId='446', homevisit=0, period=1),
#  Row(userId='446', homevisit=0, period=1),
#  Row(userId='446', homevisit=0, period=1),
#  Row(userId='446', homevisit=1, period=2),
#  Row(userId='541', homevisit=0, period=0),
#  Row(userId='541', homevisit=0, period=0),
#  Row(userId='541', homevisit=0, period=0),
#  Row(userId='541', homevisit=0, period=0),
#  Row(userId='541', homevisit=0, period=0),
#  Row(userId='541', homevisit=1, period=1),
#  Row(userId='541', homevisit=0, period=1),
#  Row(userId='541', homevisit=0, period=1),
#  Row(userId='541', homevisit=1, period=2),
#  Row(userId='541', homevisit=0, period=2),
#  Row(userId='541', homevisit=1, period=3),
#  Row(userId='541', homevisit=1, period=4),
#  Row(userId='541', homevisit=0, period=4),
#  Row(userId='541', homevisit=0, period=4),
#  Row(userId='541', homevisit=0, period=4),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=0, period=0),
#  Row(userId='970', homevisit=1, period=1),
#  Row(userId='1215', homevisit=0, period=0),
#  Row(userId='1569', homevisit=0, period=0),
#  Row(userId='1569', homevisit=0, period=0),
#  Row(userId='1569', homevisit=1, period=1),
#  Row(userId='2759', homevisit=1, period=1),
#  Row(userId='2759', homevisit=0, period=1),
#  Row(userId='2759', homevisit=0, period=1),
#  Row(userId='2759', homevisit=0, period=1),
#  Row(userId='2759', homevisit=0, period=1),
#  Row(userId='2759', homevisit=0, period=1),
#  Row(userId='2759', homevisit=0, period=1),
#  Row(userId='2759', homevisit=1, period=2),
#  Row(userId='2759', homevisit=0, period=2),
#  Row(userId='2759', homevisit=1, period=3),
#  Row(userId='30', homevisit=0, period=0),
#  Row(userId='30', homevisit=0, period=0),
#  Row(userId='406', homevisit=0, period=0),
#  Row(userId='406', homevisit=0, period=0),
#  Row(userId='1758', homevisit=0, period=0),
#  Row(userId='1758', homevisit=0, period=0),
#  Row(userId='1758', homevisit=0, period=0),
#  Row(userId='1758', homevisit=0, period=0),
#  Row(userId='2085', homevisit=0, period=0),
#  Row(userId='2085', homevisit=1, period=1),
#  Row(userId='2305', homevisit=0, period=0),
#  Row(userId='2305', homevisit=0, period=0),
#  Row(userId='2305', homevisit=1, period=1),
#  Row(userId='652', homevisit=0, period=0),
#  Row(userId='880', homevisit=0, period=0),
#  Row(userId='880', homevisit=0, period=0),
#  Row(userId='880', homevisit=0, period=0),
#  Row(userId='880', homevisit=1, period=1),
#  Row(userId='910', homevisit=0, period=0),
#  Row(userId='910', homevisit=1, period=1),
#  Row(userId='910', homevisit=0, period=1),
#  Row(userId='910', homevisit=0, period=1),
#  Row(userId='2791', homevisit=1, period=1),
#  Row(userId='2791', homevisit=0, period=1),
#  Row(userId='2791', homevisit=0, period=1),
#  Row(userId='1642', homevisit=0, period=0),
#  Row(userId='1642', homevisit=0, period=0),
#  Row(userId='1642', homevisit=0, period=0),
#  Row(userId='1642', homevisit=1, period=1),
#  Row(userId='2842', homevisit=0, period=0),
#  Row(userId='2842', homevisit=0, period=0),
#  Row(userId='2842', homevisit=1, period=1),
#  Row(userId='389', homevisit=0, period=0),
#  Row(userId='389', homevisit=0, period=0),
#  Row(userId='1282', homevisit=0, period=0),
#  Row(userId='1282', homevisit=0, period=0),
#  Row(userId='1678', homevisit=0, period=0),
#  Row(userId='1678', homevisit=0, period=0),
#  Row(userId='1678', homevisit=0, period=0),
#  Row(userId='1678', homevisit=0, period=0),
#  Row(userId='1678', homevisit=0, period=0),
#  Row(userId='1678', homevisit=1, period=1),
#  Row(userId='1678', homevisit=0, period=1),
#  Row(userId='1775', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=0, period=0),
#  Row(userId='2164', homevisit=1, period=1),
#  Row(userId='2164', homevisit=1, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  Row(userId='2164', homevisit=0, period=2),
#  ...]
